# %%
import pandas as pd
#the library is imported now lets import our data using a nice pandas function called read_csv
#we would do:
data = pd.read_csv('survey_results_public.csv')#
X = data.iloc[:,0:3]#variables
y = data.iloc[:,3]#variables
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data.iloc[:5,:33]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df = data[['MainBranch', 'Hobbyist', 'OpenSourcer', 'Employment', 'Country', 'Student', 
           'EdLevel', 'UndergradMajor','CompFreq', 'ConvertedComp','Age', 'Gender']]

# %%
df.loc[df['CompFreq'] == 'Yearly']

# %%
df
# Out:
#                                               MainBranch Hobbyist  \
# 0                 I am a student who is learning to code      Yes
# 1                 I am a student who is learning to code       No
# 2      I am not primarily a developer, but I write co...      Yes
# 3                         I am a developer by profession       No
# 4                         I am a developer by profession      Yes
# 5      I am not primarily a developer, but I write co...      Yes
# 6                         I am a developer by profession       No
# 7                            I code primarily as a hobby      Yes
# 8                         I am a developer by profession      Yes
# 9                         I am a developer by profession      Yes
# 10                           I code primarily as a hobby      Yes
# 11                I am a student who is learning to code       No
# 12                        I am a developer by profession      Yes
# ...

# %%
#import imputer
from sklearn.preprocessing import Imputer
#impute age
#we have to instantiate the imputer object with parameters that we need
imputer = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 0)#NaN means not a number. axis means which direction rows = 1, columns = 0
df.loc[:,['ConvertedComp','Age']] = imputer.fit_transform(df.loc[:,['ConvertedComp','Age']])
# Out:
# /home/kevin/.local/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df.loc[:,['ConvertedComp','Age']]
# Out:
#        ConvertedComp        Age
# 0      127110.738423  14.000000
# 1      127110.738423  19.000000
# 2        8820.000000  28.000000
# 3       61000.000000  22.000000
# 4      127110.738423  30.000000
# 5      366420.000000  28.000000
# 6      127110.738423  42.000000
# 7      127110.738423  24.000000
# 8       95179.000000  23.000000
# 9       13293.000000  30.336699
# 10     127110.738423  22.000000
# 11     127110.738423  21.000000
# 12      90000.000000  28.000000
# 13      57060.000000  31.000000
# 14     127110.738423  20.000000
# 15     455352.000000  26.000000
# 16      65277.000000  29.000000
# 17      21996.000000  30.336699
# 18      31140.000000  31.000000
# 19      41244.000000  38.000000
# 20     127110.738423  30.336699
# 21     103000.000000  47.000000
# 22      69000.000000  22.000000
# 23      26388.000000  23.000000
# 24       6300.000000  22.000000
# 25     114000.000000  34.000000
# 26     127110.738423  22.000000
# 27     127110.738423  30.336699
# ...
